# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color = "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Рамиль :)
#
# Спасибо за работу на проекте
#
# Стоит завершить фильтрацию данных, учесть пропуски при фильтрации, чтобы не потерять значительное кол-во записей, подсказку оставил
#
# Подведем итоги, мы научились и повторили на проекте каким образом:
#
# + читать тех. задание проекта
# + исследовать неочищенные данные
# + выдвигать гипотезы о пропусках данных и заполнять их значениями
# + принимать решения об удалении некачественных данных
# + находить аномалии в данных и отделять редкие значения
# + соглашаться с наличием пропусков в данных и не забывать об их наличии при фильтрации
# + строить информативные визуализации
# + делить одну выборку на две части
# + находить зависимости и распределения в данных
# + формировать выводы
#
# Навыки отработаны, проект принят
#
# <b>Поздравляю с успешно сданным третьим проектом на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color = "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Привет, Рамиль :) Спасибо за все исправления и комментарии
#
# Критические ❌ комментарии
#
# + завершить фильтрацию редких значений в п. 2.4
# + добавить расчет для выводов исследования аномалий в п.4.5
#
# добавил подсказки и бонус
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Рамиль :) Спасибо, что прислал задание :) Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://pyprog.pro/mpl/mpl_short_guide.html">Краткое руководство по Matplotlib</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос ...

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Название, краткое вступление в работу и главная задача зафиксированы.
#
# Четкий план работ и перечень основных задач позволит коллегам быстрее вникнуть в суть проекта, + будет легче  идти к главной цели проекта

# %% [markdown]
# ## Откроем файл с данными и изучим общую информацию.

# %% [markdown]
# ###  **Импортируем библиотеки pandas и matplotlib. Считаем данные из csv-файла в датафрейм и сохраним в переменную `data`. Путь к файлу:**
#
# `/datasets/real_estate_data.csv`

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from matplotlib.ticker import NullFormatter

# %%
data = pd.read_csv('https://code.s3.yandex.net/datasets/real_estate_data.csv', sep='\t', decimal='.')

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />стоит делить блок загрузки библиотек и код загрузки датасета, в случае необходимости добавления новых библиотек не придется загружать весь датасет заново и перезапускать проект целиком

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет Ринат, приятно познакомиться :)
#     блоки разделил.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Привет, Рамиль :) Взаимно :)
#
# Спасибо

# %% [markdown]
# ### **Выведем первые 20 строчек датафрейма data на экран, методом `.head()`.**

# %%
data.head(20)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1              7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2             10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3              0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4              2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6              6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7              5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9             18   5400000.0       61.00  2017-02-26T00:00:00      3
# 10             5   5050000.0       39.60  2017-11-16T00:00:00      1
# 11             9   3300000.0       44.00  2018-08-27T00:00:00      2
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# ...

# %% [markdown]
# ### **Выведем основную информацию о датафрейме с помощью метода `info()`.**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# ### **Построим гистограммы по столбцам датафрейма методом `.hist()`.**

# %%
data.hist(figsize=(15, 20));

# %% [markdown]
# ### **Выведем числовое описание данных для датафрейма методом `.describe()`.**

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  12180.000000
# mean      10.673824     34.457852      5.892358     10.569807      1.150082
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Исходя и сырых данных типичная квартира на продажу выглядит следующим образом:
# - две комнаты
# - около 52 квадратных метров
# - жилая площадь 30 кв.м
# - высота потолка 2.65 метров
# - на 4 этаже 9 этажного дома
# - кухня 9 кв.м
# - 1 балкон
# - цена 4.6 млн
# - продается за 95 дней
#
# Стоит обратить внимание на следующее:
# 1. Столбец first_day_exposition должен быть в формате datetime.
# 2. В столбце ceiling_height большое количество пропусков, а так же присутствуют выбросы. Высота потолков в объявлениях варьируется от 1м до 100м.
# 3. Размер кухонь варьируется от 1 до 112м.
# 4. В показателях удаленности от аэропортов в некоторых объявляениях стоят нули.
# 5. Выбросы присутствуют и в стоблце срок размещения, судя по нему некоторые объявления размещаются почти 5 лет.
# 6. В параметре апартаменты почти 90% данных пропущено, а так же тип должен быть булев.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> обзор данных проведен корректно

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# **Проверим названия столбцов на наличие критических ошибок**

# %%
data.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'cityCenters_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# Небольшие ошибки присутсвуют, но они не являются критическими, оставим их без изменения.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Красота стиля важна для серъезных проектов, молодец

# %% [markdown]
# ### **Найдём и изучим пропущенные значения в столбцах:**

# %% [markdown]
# **Изучим пропуски в датафрейме методом `.isna()` и просуммируем их количество по столбцам методом `.sum()`.**

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind = 'barh', figsize = (19,6), rot = 0, legend = False, fontsize = 16)
            .set_title('Количество пропущенных значений в датафрейме' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) или произошла ошибка в первой части функции ')

# %%
pass_value_barh(data)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Наглядность представления информации одна из важных составляющих работы дата-аналитика или дата-сайентиста
#
# мой график оформлен не совсем корректно, сможешь отметить, что стоило бы исправить в графике?

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Значение аргумента rotation в функции plot привело текст на графике к смещению на градус указанный в этом аргументе. Не знаю можно ли было исправить, если да то в аргументе rot = -4, исправил на 0, чуток изменил заголовок, чтобы потом тихонечко использовать твою функцию)))

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Принимается, все правильно, для оси х можно добавить название - в процентах
#
# все примеры на проекте твои :)

# %% [markdown]
# **Обработаем пропущенные значения там, где это возможно.**

# %%
# Заполним пропущенные значения количества болконов нулями
data['balcony'].fillna(value=0, inplace=True) 

# Заполним пропуски в столбце is_apartment значением False, так как апратаменты появились недавно 
# и их количество достаточно низко, предположим что отсутсвие данных означает, что это не апартаменты
data['is_apartment'].fillna(value=False, inplace=True) 

# Заполним пропуски по количеству парков и прудов в радиусе 3х км нулями
# Данный параметр влияет на привлекательность и цену жилья, 
# если его оставили не заполненным, то скорее всего их рядом нет
data['parks_around3000'].fillna(value=0, inplace=True)       
data['ponds_around3000'].fillna(value=0, inplace=True)

# Проверим есть ли пропуски в расстоянии до парка или пруда при наличии парков или прудов в радиусе 3х км
data_ponds = data[data['ponds_around3000'] > 0] 
data_parks = data[data['parks_around3000'] > 0]
#print('Количество NaN в столбце ponds_nearest:', data_ponds['ponds_nearest'].isnull().sum())
#print('Количество NaN в столбце parks_nearest:', data_parks['parks_nearest'].isnull().sum())

# Пропусков при описанном выше условии нет, предположим, что такие пропуски соответствуют 
# нулям и пропускам в столбцах ponds_around3000 и parks_around3000, поэтому заполним их нулями
data['ponds_nearest'].fillna(value=0, inplace=True)
data['parks_nearest'].fillna(value=0, inplace=True)

# Восстановить данные по этажности не представляется возможным, а так число объявлений без указания этажности 
# не превышает 0.4% этими данными можно пренебречь
data.dropna(subset=['floors_total'], inplace=True)

# Аналогичная ситуация с названием населенного пункта
data.dropna(subset=['locality_name'], inplace=True)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  float64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  object
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        14481 non-null  float64
#  6   floors_total          23565 non-null  float64
#  7   living_area           21700 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          21343 non-null  float64
#  13  balcony               23565 non-null  float64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />не стоит использовать подобный подход к обработке аномалий
#
#         # Создадим функцию для удаления данныx которые выделяются из 1.5кратного размаха квартилей
#         def quartile_range(df, column):
#             q1 = df[column].quantile(0.25)
#             q3 = df[column].quantile(0.75)
#             irq = q3 - q1
#             dfq = df.loc[(df[column] < q3 + 1.5*irq) & (df[column] > q1 - 1.5*irq), column]
#             return dfq
#         # Укажем столбцы в которых есть выбросы
#         quartile_columns = ['total_area', 'kitchen_area', 'living_area', 'days_exposition', 'rooms']
#
#         # С помощью цикла применим созданную функцию к датафрейму
#         for col in quartile_columns:
#             data[col] = quartile_range(data, col)
#
# пояснение будет в п.2.4.1

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Удалил этот пункт, так как работу с аномалияму буду делать в других пунктах. Эх, а я казался себе таким умным когда это делал, показалось))

# %% [markdown]
# **Обработаем пропуски в жилой площади и кухне**

# %%
data.isna().sum()
# Out:
# total_images               0
# last_price                 0
# total_area                 0
# first_day_exposition       0
# rooms                      0
# ceiling_height          9084
# floors_total               0
# living_area             1865
# floor                      0
# is_apartment               0
# studio                     0
# open_plan                  0
# kitchen_area            2222
# balcony                    0
# locality_name              0
# airports_nearest        5524
# cityCenters_nearest     5501
# parks_around3000           0
# parks_nearest              0
# ponds_around3000           0
# ponds_nearest              0
# days_exposition         3171
# dtype: int64

# %%
data['living_area'] = data['living_area'].fillna(0)
data['kitchen_area'] = data['kitchen_area'].fillna(0)

# %%
# Удалим данные которые изначально были неправильными
bad_data = data.query('total_area*0.9 <= (living_area + kitchen_area)')
bad_index = bad_data.index

print(bad_index)

data.drop(bad_index, inplace=True)
data.reset_index(drop=True, inplace=True)
# Out:
# Int64Index([   41,   171,   184,   220,   319,   354,   368,   440,   481,
#               491,
#             ...
#             23097, 23108, 23139, 23185, 23202, 23216, 23297, 23328, 23521,
#             23680],
#            dtype='int64', length=489)

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />После заполнения синтетическими данными столбцов, стоит провести проверку на корректность значений всех наших площадей, т.к. есть (коридоры, сан.узлы, балконы)
#
#         total_area*0.9 <= (living_area + kitchen_area)
#
# если алгоритм приводит к появлению аномалий, стоит подумать над его содержимым

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента В1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Изменил алгоритм, аномалии все равно появляются, но их количество очень низкое, в весь датафрейм добавилось 124 аномалии, 475 было изначально, стало 599, их нужно удалить или оставить? Я немножко запутался.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Да аномалии можно удалить, мы пока укладываемся в 10%, если перестанет, то можно вместо аномальных значений жилой и кухонной площадей выставить пропуски или маркеры (-1)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента В2 </b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Удалил алгоритм заполнения пропусков, удалил строчки где кухня+жилая были больше общей*0.9

# %%
# check
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='living_area' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'black', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — Жилая');

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Аномалии проявились на графике (прямая неестественная для облака линия) — стоит принять решение или изменить алгоритм заполнения пропусков, или оставить пропуски, или заполнить маркерами
#
# при изменении способа обработки колонок, стоит перепроверить код фильтрации
#
# __Самое важное — приобрести навык__ — любая замена пропусков очень трудоемка по ресурсам, т.к. приходится искать оптимальный вариант и если можно работать, имея пропуски в данных — лучше отказаться от заполнения
#
# но есть другие случаи, когда пропуски заполнять обязательно нужно, на проекте по стат. анализу — внимательно посмотри на пропуски в данных в объединенной таблице (кроме даты оттока клиентов)
#
# в итоге каждый раз мы вынуждены будем принимать решение — заполнять пропуски и как заполнять, или оставлять

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента В2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Пытался заполнить данные по разному, даже хотел добавить гауссовский шум, но навыка не хватило, демотивировался полностью и поставил везде 0. Учитывать эти данные в анализе не буду. На этапе анализа, что с медианными значениями, что вообще без этих данных, результат получился идентичным.

# %% [markdown]
# ### **Преобразуем тип данных в столбцах**

# %%
# вряд ли кто-то указывает цену квартиры до копеек, изменим тип данных столбца last_price на integer
# изменим тип данных столбца floors_total на integer
# изменим тип данных столбца balcony на integer
# изменим тип данных столбца parks_around3000 и parks_nearest на integer, не думаю что может быть 2,73 парка поблизости
# изменим тип данных столбца ponds_around3000 и ponds_nearest на integer, по аналогичной с парком причине
# изменим все измерения расстояний на integer, никому не нужны эти расстояния вплоть до сантиметров
columns_to_int = ['last_price', 'floors_total', 'balcony', 'airports_nearest', 'cityCenters_nearest', 'parks_around3000',
               'parks_nearest', 'ponds_around3000', 'ponds_nearest', 'days_exposition']

for column in columns_to_int:
    data[column] = data[data[column].notnull()][column].astype('int')

# %%
# изменим тип данных столбца first_day_exposition на datetime
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')
# изменим тип данных столбца is_apartment на bool, т.к. тут лишь 2 варианта, да/нет
data['is_apartment'] = data['is_apartment'].astype('bool')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23076 entries, 0 to 23075
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23076 non-null  int64
#  1   last_price            23076 non-null  int64
#  2   total_area            23076 non-null  float64
#  3   first_day_exposition  23076 non-null  datetime64[ns]
#  4   rooms                 23076 non-null  int64
#  5   ceiling_height        14171 non-null  float64
#  6   floors_total          23076 non-null  int64
#  7   living_area           23076 non-null  float64
#  8   floor                 23076 non-null  int64
#  9   is_apartment          23076 non-null  bool
#  10  studio                23076 non-null  bool
#  11  open_plan             23076 non-null  bool
#  12  kitchen_area          23076 non-null  float64
#  13  balcony               23076 non-null  int64
#  14  locality_name         23076 non-null  object
# ...

# %% [markdown]
# **Вывод:**
#
# **Изменил тип данных в соответствии с данными в столбцах, подробно описал почему при выполнении каждого изменения.**

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />цикл for остался без работы
#
#
#             ....
#             data['floors_total'] = data['floors_total'].astype('int')
#             # изменим тип данных столбца balcony на integer
#             data['balcony'] = data['balcony'].astype('int')
#             # изменим тип данных столбца parks_around3000 на integer, не думаю что может быть 2,73 парка поблизости
#             data['parks_around3000'] = data['parks_around3000'].astype('int')
#             # изменим тип данных столбца ponds_around3000 на integer, по аналогичной с парком причине
#             data['ponds_around3000'] = data['ponds_around3000'].astype('int')

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Нашел ему подработку :)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />принимается

# %% [markdown]
# ### **Обработаем неявные дубликаты в `locality_name`, добавим новые названия в столбец `short_locality_name`**

# %%
# создадим функцию для обработки имен населенных пунктов

def make_short_name(row):
    #print(1, row)
    split_name = row.split()
    new_name = []
    for word in split_name:
        if word[0].isupper():
            new_name.append(word)
    new_name = ' '.join(word for word in new_name)
    #print(2, new_name)
    return new_name

    
data['short_locality_name'] = data['locality_name'].apply(make_short_name)
data['short_locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'Шушары', 'Янино-1', 'Парголово', 'Мурино',
#        'Ломоносов', 'Сертолово', 'Петергоф', 'Пушкин', 'Кудрово',
#        'Коммунар', 'Колпино', 'Красный Бор', 'Гатчина', 'Фёдоровское',
#        'Выборг', 'Кронштадт', 'Кировск', 'Новое Девяткино',
#        'Металлострой', 'Лебяжье', 'Сиверский', 'Молодцово',
#        'Кузьмоловский', 'Новая Ропша', 'Павловск', 'Пикколово',
#        'Всеволожск', 'Волхов', 'Кингисепп', 'Приозерск', 'Сестрорецк',
#        'Куттузи', 'Аннино', 'Ефимовский', 'Плодовое', 'Заклинье',
#        'Торковичи', 'Первомайское', 'Красное Село', 'Понтонный',
#        'Сясьстрой', 'Старая', 'Лесколово', 'Новый Свет', 'Сланцы',
#        'Путилово', 'Ивангород', 'Шлиссельбург', 'Никольское',
#        'Зеленогорск', 'Сосновый Бор', 'Оржицы', 'Кальтино', 'Романовка',
#        'Бугры', 'Рощино', 'Кириши', 'Луга', 'Волосово', 'Отрадное',
#        'Павлово', 'Оредеж', 'Копорье', 'Молодёжное', 'Тихвин', 'Победа',
# ...

# %%
# check
data.short_locality_name.nunique()
# Out:
# 303

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />хорошая работа по избавлению от неявных дубликатов

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# Для того, __чтобы изменить лишь часть строки,__ можно добавить к коду — .str
#
#         .str.replace('посёлок','поселок')
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.replace.html

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит исследовать выборку
#
#
# + __на простое дублирование записей__
#  + __особенно это станет важным, когда мы перейдем к более сложным задачам на втором модуле курса__
#
# <br />
#
# + дополнительно — на рабочих проектах стоит искать дубликаты по сумме ключевых параметров (подмножеству), для примера:
#
#  + общ. площадь квартиры,
#  + этаж,
#  + общая этажность дома,
#  + расстояние до центра
#  + название населенного пункта
#  + кол-во комнат
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html?highlight=duplicat#pandas.DataFrame.duplicated

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Честно пытался понять для чего, но не понял :(
#         если пояснишь, буду очень благодарен

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для поиска неявных дубликатов, когда у одной и той же квартиры будут отличаться только дата объявления и второстепенные параметры: кол-во балконов, расстояние до парка и т.д.

# %% [markdown]
# ### **Найдем и устраним редкие и выбивающиеся значения.**

# %% [markdown]
# **Обработаем аномальные значения, там где это возможно и заполним пропуски появившиеся на их месте**

# %% [markdown]
# #### check nan

# %%
# Возьмем за условный радиус Санкт-Петербурга 18 км 
# чтобы посчитать высоту потолков в зависимости от удаленности от центра и создадим новый столбец
def ceiling_height_fill(row):
    try:
        if row['cityCenters_nearest'] < 2500:
            return 'центр'
        elif row['cityCenters_nearest'] < 5000:
            return 'почти центр'
        elif row['cityCenters_nearest'] < 18000:
            return 'районы города'
        elif row['cityCenters_nearest'] >= 18000:
            return 'область'
    except:
        pass
    
data['distance_from_center'] = data.apply(ceiling_height_fill, axis=1)


display(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23076 entries, 0 to 23075
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23076 non-null  int64
#  1   last_price            23076 non-null  int64
#  2   total_area            23076 non-null  float64
#  3   first_day_exposition  23076 non-null  datetime64[ns]
#  4   rooms                 23076 non-null  int64
#  5   ceiling_height        14171 non-null  float64
#  6   floors_total          23076 non-null  int64
#  7   living_area           23076 non-null  float64
#  8   floor                 23076 non-null  int64
#  9   is_apartment          23076 non-null  bool
#  10  studio                23076 non-null  bool
#  11  open_plan             23076 non-null  bool
#  12  kitchen_area          23076 non-null  float64
#  13  balcony               23076 non-null  int64
#  14  locality_name         23076 non-null  object
# ...

# %%
# Заполним пропуски в высоте потолков сначала по удаленности от центра, 
# потом по названию населенного пункта                         
for fill in data[['distance_from_center', 'short_locality_name']]:
    (data['ceiling_height']
     .fillna(data.groupby([fill])['ceiling_height']
             .transform('median'), inplace=True))

display(data.shape[0])
# Out:
# 23076

# %%
# Заменим аномальные значения на подходящие по смыслу либо среднее    
data['ceiling_height'] = (data['ceiling_height']
                          .replace({32 : 3.2, 24 : 2.4, 27.5 : 2.75, 27 : 2.7, 26 : 2.6, \
                                    25 : 2.5, 10 : 2.7, 5.8 : 2.7, 100 : 2.7, 1 : 2.7, 1.2 : 2.7, \
                                    8.3 : 2.7, 14 : 2.7, 1.75 : 2.7, 8 : 2.7,  20 : 2.7, \
                                    6 : 2.7, 22.6 : 2.7, 10.3 : 2.7})
)

# После обработки осталось 79 пропусков, они не влияют на последующий анализ, поэтому оставим их без изменений

# %%
data.isna().sum()
# Out:
# total_images               0
# last_price                 0
# total_area                 0
# first_day_exposition       0
# rooms                      0
# ceiling_height            87
# floors_total               0
# living_area                0
# floor                      0
# is_apartment               0
# studio                     0
# open_plan                  0
# kitchen_area               0
# balcony                    0
# locality_name              0
# airports_nearest        5391
# cityCenters_nearest     5368
# parks_around3000           0
# parks_nearest              0
# ponds_around3000           0
# ponds_nearest              0
# days_exposition         3092
# short_locality_name        0
# distance_from_center    5368
# dtype: int64

# %%
data = data.query('floors_total > 1 & (20 < total_area < 250 & rooms < 6) \
& (500_000 < last_price < 30_000_000) & floors_total < 38 \
& days_exposition != 1 & days_exposition != 2 & 2.4 < ceiling_height < 4')
display(data.shape[0])
data.describe()
# Out:
# 22381
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  22381.000000  2.238100e+04  22381.000000  22381.000000    22381.000000
# mean       9.836960  5.650396e+06     57.270387      2.008579        2.690771
# std        5.640282  3.822993e+06     25.030088      0.954514        0.205265
# min        0.000000  5.200000e+05     20.100000      0.000000        2.450000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.550000
# 50%        9.000000  4.600000e+06     51.000000      2.000000        2.650000
# 75%       14.000000  6.550000e+06     68.000000      3.000000        2.710000
# max       50.000000  2.999900e+07    240.000000      5.000000        3.980000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  22381.000000  22381.000000  22381.000000  22381.000000  22381.000000
# mean      10.829185     29.882408      5.937492      9.227210      0.599303
# ...

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#     data = data.query('ceiling_height < 5')
#
# Так мы познакомились с особенностью фильтрации в библиотеке пандас, все NaN убегают вместе со значениями, которые не подходят под нашу фильтрацию, поэтому процент потери записей огромен
#
# минус 2000 записей
#
# стоит настроить условия фильтрации, чтобы не потерять записи с пропусками
#
# <b>алгоритм фильтрации столбца с пропусками: задаем основное условие фильтрации, + прибавляем условие не трогать записи с пропусками</b>
#
# стоит обратить внимание на весь код фильтрации, т.к. в нескольких колонках встречаются пропуски

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> больше не актуально
#
#         Понял, принял, убрал, добавил новое, минусанул 1400 записей :D процентов 40 из них были некорректны изначально, но в этот раз сохранилось 22243 строки, удалил около 6% записей. Не совсем понял как обрабатывать аномальные значения если их не удалять, они влияют на среднее и медиану.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Молодец, что учел физические характеристики выборки
#
# ... если рассмотреть районность высоты потолков, т.к. в современных районах Питера высота потолков будет ожидаема ниже, чем в исторических, мы увидим, что заполнение подобного объема пропусков медианой или средним значением «размажет» это отличительное свойство объектов недвижимости в центре Питера
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)

# %%
# Заполним пропуски в удаленности от центра в зависимости от названия населенного пункта где возможно
data['cityCenters_nearest'] = data['cityCenters_nearest'].fillna \
(data.groupby('short_locality_name')['cityCenters_nearest'].transform('median'))

# аналогично поступим с аэропортами
data['airports_nearest'] = data['airports_nearest'].fillna \
(data.groupby('short_locality_name')['airports_nearest'].transform('median'))

# %%
# check
data.shape[0]
display(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22381 entries, 0 to 23075
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          22381 non-null  int64
#  1   last_price            22381 non-null  int64
#  2   total_area            22381 non-null  float64
#  3   first_day_exposition  22381 non-null  datetime64[ns]
#  4   rooms                 22381 non-null  int64
#  5   ceiling_height        22381 non-null  float64
#  6   floors_total          22381 non-null  int64
#  7   living_area           22381 non-null  float64
#  8   floor                 22381 non-null  int64
#  9   is_apartment          22381 non-null  bool
#  10  studio                22381 non-null  bool
#  11  open_plan             22381 non-null  bool
#  12  kitchen_area          22381 non-null  float64
#  13  balcony               22381 non-null  int64
#  14  locality_name         22381 non-null  object
# ...

# %%
# Надеюсь так можно было :) украл твою функцию для визуализации оставшихся пропусков после обработки
pass_value_barh(data)

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# в результате выполнения кода
#
#
#         # С помощью цикла применим созданную функцию к датафрейму
#         for col in quartile_columns:
#             data[col] = quartile_range(data, col)
#
# мы создали пропуски в колонках
#
# а кодом
#
#         data.dropna(subset=['total_area', 'rooms'], inplace=True)
#
# удалили еще одну тысячу записей
#
# Стоит исправить весь код фильтрации ....

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Старался как мог, сохранил сколько получилось.

# %% [markdown]
# **Выводы:**
#
# - **Высота потолков** - треть данных отсутствовала, присутствовали аномально высокие значения. Так как мы анализируем Петербург было логично заполнить пропуски медианными значениями в зависимости от удаленности от центра города. Так как в центра большинство домов построенных в Российской империи, с высокими потолками, а ближе к границам города и в области чаще встречается типовая советская застройка.
# - **Жилая площадь** - обнаружены некоторые пропуски в размере жилой площади, заполнил их медианными значениеми в зависимости от общей площади квартиры
# - **Апартаменты** - самое большое количество пропусков обнаружено в колонке апартаменты, пропуски могут быть связаны с тем, что апартаменты как класс появились совсем недавно и люди когда видят данный параметр не понимают что он означает. Люди которые знают что продают апартаменты скорее всего отмечают данный параметр. Заполнил все пропуски значением False.
# - **Балкон** - данный параметр так же имеет большое количество пропусков, это может быть связано с тем что, продавцы не считают необходимым отмечать данный пункт при продаже квартиры без балкона. Заменил все пропуски значением 0.
# - **Количество парков/прудов в 3х км** - скорее всего повторилась ситуация как с балконом, если их нет, то и не надо отмечать.
# - **Расстояние до ближайшего парка/пруда** - данном параметре больше пропусков чем в столбце с их количеством. Это обусловлено тем, что все пропуски появились там, где наличие парка либо пропущено либо равно нулю. Заполнил все пропуски нулями. Данные выбросы позже удалил, обработав аномальные значения по квартилям.
# - **Расстояние до аэропорта и количество дней размещения** - пропуски в данных столбцах восстановить невозможно, оставил данные без изменений.
#
# Удалил пропуски в столбцах locality_name и total_floors, заполнить их не представляется возможных, а их количество является нерепрезентативной выборкой которой можно пренебречь.

# %% [markdown]
# #### check gap

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22381 entries, 0 to 23075
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          22381 non-null  int64
#  1   last_price            22381 non-null  int64
#  2   total_area            22381 non-null  float64
#  3   first_day_exposition  22381 non-null  datetime64[ns]
#  4   rooms                 22381 non-null  int64
#  5   ceiling_height        22381 non-null  float64
#  6   floors_total          22381 non-null  int64
#  7   living_area           22381 non-null  float64
#  8   floor                 22381 non-null  int64
#  9   is_apartment          22381 non-null  bool
#  10  studio                22381 non-null  bool
#  11  open_plan             22381 non-null  bool
#  12  kitchen_area          22381 non-null  float64
#  13  balcony               22381 non-null  int64
#  14  locality_name         22381 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __проверим какие аномалии остались__ таблица ниже

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир
# сырые данные

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max', 'median'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_74c55_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_74c55_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_74c55_row0_col0" class="data row0 col0" >22,381.00</td>
#                         <td id="T_74c55_row0_col1" class="data row0 col1" >22,381.00</td>
# ...

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости (в т.ч. и хвосты) в колонках:
#
#         'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area', 'floors_total'
#
# стоит обратить внимание на минимальные и максимальные значения в выборке и учесть наличие пропусков при фильтрации данных

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Вроде как аномалии все подчистил, кроме дней размещения. Там около 8 тысяч аномальных строк, а если судить по времени размещения объявлений на сайте яндекс.недвижимости и того больше, их буду фильтровать при построении графиков тогда уже.

# %%
# check
data.hist(column = 'days_exposition', bins = 50, figsize = (15,3), range = (0,5));

data.hist(column = 'days_exposition', bins = 50, figsize = (15,3), range = (0,5))
plt.ylim(0, 40);

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости (в т.ч. и хвосты) в колонках:
#
#          'ceiling_height', 'days_exposition', 'floors_total'
#
# для определения хвостов, редкостей и аномалий смотрим на минимальные и максимальные значения, строим несколько гистограмм по каждому параметру
#
# например по таблице мы видим аномалию квартиру в здании на 60 этажей  ..., а по гистограмме аномальную скорость продаж в один или два дня
#
# стоит учесть наличие пропусков при фильтрации данных

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента B2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Вроде больше не осталось

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Выборка data['days_exposition'] имеет длинный правый хвост, стоит обрезать подобный хвост, оптимально ориентироваться на значения 0,99 квантиля, это где-то 1200 дней ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Доп. задание, на твое усмотрение — сможешь добавить в таблицу расчет медианного значения?
#
#         (
#             data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
#                   'floor', 'floors_total']]
#             .apply (['count', 'min', 'max'])
#             .style.format("{:,.2f}")
#         )

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Если я правильно понял задачу, то добавил, если нет, то нет)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />принимается

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для выполнения пункта 2.4. существует два подхода
#
# Можно механически бороться с выбросами, ...
#
# основная проблема такого подхода — не учитывается неоднородность нашей выборки: у нас здесь и малые поселки, и вторая столица страны, и исторический фонд и массовая застройка, и однушки и довольно большое кол-во многокомнатных квартир, или наоборот одна две квартиры с количеством комнат больше 7-ми ...
#
#
#
# если бы у нас в таблице были бы только однокомнатные квартиры из определенного района массовой застройки, тогда да, мы бы боролись с выбросами традиционными способами, при нашем многообразии населенных пунктов, многокомнатности такие подходы не работают... т.е. они работают, но это усложнит наш проект — придется разбить и объединить записи нашей таблицы по нескольким параметрам (кол-во комнат, район, и т.д.), а затем только выполнять все остальные пункты на каждой отдельной выборке
#
# Остается другой подход — убираем редкие значения и следим за количеством потерь...
#
# Для выборки из 23-х тысяч значений, несколько записей со стоимостью квадратного метра выше 1-го млн. руб., довольно редкое явление
#
# Хороший пример, высота потолков, которую мы отрезаем по нижней и верхней планке, это скорее аномальные записи, посмотрим на другой аспект — на редкости: кол-во комнат
#
# __т.е. мы не говорим о том, что квартир с кол-ом комнат выше 7 не бывает, мы говорим, что для нашего исследования это редкие выбивающиеся из общей картины уникальные объекты, по которым необходимо проводить отдельную работу ...__
#
# подобным образом рассматриваем и остальные параметры
#
# наши помощники
#
# 1. гистограммы, с хорошим масштабом
# 2. метод describe() или облегченная версия, пример выше
# 3. метод value_counts()
#
# плюс жизненный опыт

# %%
# check

try:
    df_check = pd.read_csv('https://code.s3.yandex.net/datasets/real_estate_data.csv', sep='\t')
# если не получилось прочитать файл из локальной папки, то загружаем данные из сети
except:
    df_check = pd.read_csv('real_estate_data.csv', sep='\t')

# %%
# check
df_check.rooms.value_counts().to_frame()
# Out:
#     rooms
# 1    8047
# 2    7940
# 3    5814
# 4    1180
# 5     326
# 0     197
# 6     105
# 7      59
# 8      12
# 9       8
# 10      3
# 11      2
# 14      2
# 19      1
# 16      1
# 12      1
# 15      1

# %%
# check
df_check.total_area.hist(bins = 150, figsize = (15,3));

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />т.е. все квартиры менее 20-ти и более 250-ти квадратных метров можно считать редкостями

# %%
# check
df_check.total_area.hist(bins = 150, figsize = (15,3), range = (180,500));

# %%
# check
df_check.total_area.hist(bins = 15, figsize = (15,3), range = (180,500));

# %%
# check
df_check.total_area.hist(bins = 15, figsize = (15,3), range = (0,25));

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Осталось завершить выполнение пункта 2.4 из брифа проекта
#
# 2.4.	Найдите и устраните редкие и выбивающиеся значения.
#
# __Критичный уровень потерь записей на этапе предобработки составляет 10%, оптимальный 5%__

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> На всей предобработке потерял 6% записей.

# %%
# check

# Значения параметров объектов недвижимости на разных квантилях

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  
        'kitchen_area', 'floor',   'floors_total']]
    .quantile([0.0012, 0.01, .5, .99, .9988]) # выбираем размах в 0,9976 квантилей 
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_6335f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6335f_level0_row0" class="row_heading level0 row0" >0.0012</th>
#                         <td id="T_6335f_row0_col0" class="data row0 col0" >0.00</td>
#                         <td id="T_6335f_row0_col1" class="data row0 col1" >22.00</td>
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Квантили что это такое
#
# https://fin-accounting.ru/cfa/l1/quantitative/cfa-quartiles-quintiles-deciles-percentiles?ysclid=l7gy2kky4i156375632
#
# они помогают увидеть редкости и аномалии в данных

# %% [markdown]
# ## **Добавим в таблицу новые столбцы со следующими параметрами:**

# %% [markdown]
# - цена одного квадратного метра;
# - день недели публикации объявления (0 — понедельник, 1 — вторник и так далее);
# - месяц публикации объявления;
# - год публикации объявления;
# - тип этажа квартиры (значения — «‎первый», «последний», «другой»);
# - расстояние до центра города в километрах (переведем из м в км и округлим до целых значений).

# %%
# добавим столбец с ценой одного квадратного метра
data['price_sqm'] = data['last_price'] / data['total_area'] 
data['price_sqm'] = data['price_sqm'].astype('int')

# Добавим столбец с ценой в млн.р для удобного отображения цены на графиках.
data['price_mln'] = data['last_price'] / 1_000_000

# добавим столбцы день недели публикации, месяц и год
data['weekday'] = data['first_day_exposition'].dt.weekday
data['month'] = data['first_day_exposition'].dt.month
data['year'] = data['first_day_exposition'].dt.year

# %%
# добавим в новый столбец категории для этажей
def categorize_floor(row):
    if row['floor'] == 1:
        return 'первый'
    elif row['floor'] == row['floors_total']:
        return 'последний'
    elif row['floor'] <= 0:
        return 'подвал'
    else:
        return 'другой'

# %%
data['floor_category'] = data.apply(categorize_floor, axis=1)


# добавим расстояние до центра в километрах и округлим до целых значений
data['dist_center_km'] = data['cityCenters_nearest'] / 1000
data = data.round({'dist_center_km': 0})

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Функция хорошая, стоит учесть крайние условия: нулевые и отрицательные значения

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделано.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />подвалы :)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит делить код с функцией и остальным кодом, чтобы была возможность для отладки функции

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделано.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> данные добавлены корректно, молодец

# %% [markdown]
# ## Проведем исследовательский анализ данных

# %% [markdown]
# ### **Изучим следующие параметры объектов:**

# %% [markdown]
# - общая площадь
# - жилая площадь
# - площадь кухни
# - цена объекта
# - количество комнат
# - высота потолков
# - этаж квартиры
# - тип этажа квартиры («первый», «последний», «другой»)
# - общее количество этажей в доме
# - расстояние до центра города в метрах
# - расстояние до ближайшего аэропорта
# - расстояние до ближайшего парка
# - день и месяц публикации объявления

# %%
# Построим гистограмму для общей площади квартир
data.plot(kind='hist', y='total_area', range=(20, 240), bins=200,
label='общая площадь', figsize=(15, 5))
plt.minorticks_on()
plt.grid(which='major', color = '#444', linewidth = 0.5)
plt.grid(which='minor', color='#aaa', ls=':')
plt.xlabel('Общая площадь')
plt.ylabel('Количество объявлений')
data['total_area'].describe()
# Out:
# count    22381.000000
# mean        57.270387
# std         25.030088
# min         20.100000
# 25%         40.000000
# 50%         51.000000
# 75%         68.000000
# max        240.000000
# Name: total_area, dtype: float64

# %%
# Построим гистограмму для жилой площади квартир
data.plot(kind='hist', y='living_area', range=(1, 80), bins=150,
label='жилая площадь', figsize=(15, 5))
plt.minorticks_on()
plt.grid(which='major', color = '#444', linewidth = 0.5)
plt.grid(which='minor', color='#aaa', ls=':')
plt.xlabel('Жилая площадь')
plt.ylabel('Количество объявлений')
data.query('living_area > 0')['living_area'].describe()
# Out:
# count    20612.000000
# mean        32.447029
# std         16.153112
# min          2.000000
# 25%         18.400000
# 50%         30.000000
# 75%         41.400000
# max        154.000000
# Name: living_area, dtype: float64

# %%
# Построим гистограмму для площади кухонь
data.plot(kind='hist', y='kitchen_area', range=(1, 70), bins=200,
label='площадь кухни', figsize=(15, 5))
plt.minorticks_on()
plt.grid(which='major', color = '#444', linewidth = 0.5)
plt.grid(which='minor', color='#aaa', ls=':')
plt.xlabel('Площадь кухни')
plt.ylabel('Количество объявлений')
data.query('kitchen_area > 0')['kitchen_area'].describe()
# Out:
# count    20294.000000
# mean        10.176121
# std          4.857224
# min          1.300000
# 25%          7.000000
# 50%          9.000000
# 75%         11.600000
# max         70.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Хорошие графики, можно добавить кол-во корзин к параметрам гистограммы и изменить размер у графиков (увеличить ширину)
#
# Подписи осей на графиках и название добавят ясности и читабельности.
# Это важные элементы любой визуализации. Как добавить подписи и названия, смотри [здесь](https://pyprog.pro/mpl/mpl_axis_signatures.html) и [там](https://pyprog.pro/mpl/mpl_title.html), и
#
# [тут](https://proproprogs.ru/modules/matplotlib-razmeshchaem-standartnye-tekstovye-elementy-na-grafike?ysclid=l6agtioc6f299002507)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделал, вроде

# %%
# Изучим цену объектов
data.plot(kind='hist', y='price_mln', range=(0, 30), bins=200,
label='цена объекта', figsize=(15, 5))
plt.minorticks_on()
plt.grid(which='major', color = '#444', linewidth = 0.5)
plt.grid(which='minor', color='#aaa', ls=':')
plt.xlabel('Цена объекта')
plt.ylabel('Количество объявлений')
data['last_price'].describe()
# Out:
# count    2.238100e+04
# mean     5.650396e+06
# std      3.822993e+06
# min      5.200000e+05
# 25%      3.400000e+06
# 50%      4.600000e+06
# 75%      6.550000e+06
# max      2.999900e+07
# Name: last_price, dtype: float64

# %%
# Изучим количество комнат
data.plot(kind='hist', y='rooms', range=(0, 5), bins=11,
label='количество комнат', figsize=(15, 5))
plt.minorticks_on()
plt.grid(which='major', color = '#444', linewidth = 0.5)
plt.grid(which='minor', color='#aaa', ls=':')
plt.xlabel('Количество комнат')
plt.ylabel('Количество объявлений')
data['rooms'].describe()
# Out:
# count    22381.000000
# mean         2.008579
# std          0.954514
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          5.000000
# Name: rooms, dtype: float64

# %%
# Изучим высоту потолков
data.plot(kind='hist', y='ceiling_height', range=(2, 5), bins=120,
label='высота потолков', figsize=(15, 5))
plt.minorticks_on()
plt.grid(which='major', color = '#444', linewidth = 0.5)
plt.grid(which='minor', color='#aaa', ls=':')
plt.xlabel('Высота потолков')
plt.ylabel('Количество объявлений')
data['ceiling_height'].describe()
# Out:
# count    22381.000000
# mean         2.690771
# std          0.205265
# min          2.450000
# 25%          2.550000
# 50%          2.650000
# 75%          2.710000
# max          3.980000
# Name: ceiling_height, dtype: float64

# %%
# Изучим распределение по категориям этажей 
data['floor_category'].hist(bins=5, figsize=(15, 5));
plt.xlabel('Цена объекта')
plt.ylabel('Количество объявлений');

# %%
# Изучим распределение по этажам 
data.plot(kind='hist', y='floor', range=(0, 34), bins=70,
label='этаж квартиры', figsize=(15, 5))
plt.minorticks_on()
plt.grid(which='major', color = '#444', linewidth = 0.5)
plt.grid(which='minor', color='#aaa', ls=':')
plt.xlabel('Этаж квартиры')
plt.ylabel('Количество объявлений')
data['floor'].describe()
# Out:
# count    22381.000000
# mean         5.937492
# std          4.897573
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          8.000000
# max         33.000000
# Name: floor, dtype: float64

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит изменить параметры отображения гистограммы (добавить корзин), сейчас трудно определить границу резкого снижения кол-ва объявлений, или на 4-ке, или на 5-ке, или на 6-ке ...

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Добавил

# %%
# Изучим этажность домов в объявлениях
data.plot(kind='hist', y='floors_total', range=(0, 30), bins=60,
label='этажей в доме', figsize=(15, 5))
plt.minorticks_on()
plt.grid(which='major', color = '#444', linewidth = 0.5)
plt.grid(which='minor', color='#aaa', ls=':')
plt.xlabel('Этажей в доме')
plt.ylabel('Количество объявлений')
data['floors_total'].describe()
# Out:
# count    22381.000000
# mean        10.829185
# std          6.593366
# min          2.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         37.000000
# Name: floors_total, dtype: float64

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит изменить параметры отображения гистограммы (добавить корзин), сейчас  трудно определить типовую высотность зданий

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Добавил

# %%
# Изучим расстояние до центра города в метрах
data.plot(kind='hist', y='cityCenters_nearest', range=(0, 66000), bins=200,
label='расстояние до центра', figsize=(15, 5))
plt.minorticks_on()
plt.grid(which='major', color = '#444', linewidth = 0.5)
plt.grid(which='minor', color='#aaa', ls=':')
plt.xlabel('Расстояние до центра')
plt.ylabel('Количество объявлений')
data['cityCenters_nearest'].describe()
# Out:
# count    17229.000000
# mean     14480.709008
# std       8568.447937
# min        208.000000
# 25%       9794.000000
# 50%      13246.000000
# 75%      16446.000000
# max      65968.000000
# Name: cityCenters_nearest, dtype: float64

# %%
# Изучим расстояние до ближайшего аэропорта
data.plot(kind='hist', y='airports_nearest', range=(1, 85000), bins=200,
label='расстояние до аэропорта', figsize=(15, 5))
plt.minorticks_on()
plt.grid(which='major', color = '#444', linewidth = 0.5)
plt.grid(which='minor', color='#aaa', ls=':')
plt.xlabel('Расстояние до аэропорта')
plt.ylabel('Количество объявлений')
data.query('airports_nearest > 0')['airports_nearest'].describe()
# Out:
# count    17228.000000
# mean     28896.366264
# std      12749.494764
# min       6450.000000
# 25%      18445.250000
# 50%      27059.000000
# 75%      37434.000000
# max      84869.000000
# Name: airports_nearest, dtype: float64

# %%
# Изучим расстояние до ближайшего парка
data.plot(kind='hist', y='parks_nearest', range=(1, 3200), bins=200,
label='расстояние до парка', figsize=(15, 5))
plt.minorticks_on()
plt.grid(which='major', color = '#444', linewidth = 0.5)
plt.grid(which='minor', color='#aaa', ls=':')
plt.xlabel('Расстояние до парка')
plt.ylabel('Количество объявлений')
data.query('parks_nearest > 0')['parks_nearest'].describe()
# Out:
# count    7471.000000
# mean      494.797350
# std       344.104038
# min         1.000000
# 25%       290.000000
# 50%       456.000000
# 75%       616.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %%
# Изучим день размещения объявления
data.plot(kind='hist', y='weekday', range=(0, 6), bins=14,
label='день размещения объявления', grid=True, figsize=(15, 5));
plt.xlabel('День размещения объявления')
plt.ylabel('Количество объявлений');

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />стоит поправить параметр
#
#         data.plot(kind='hist', y='weekday', range=(1, 7), bins=14,
#
# range=(1, 7), у нас понедельник = 0

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделано

# %%
# Изучим месяц размещения объявления
data.plot(kind='hist', y='month', range=(1, 12), bins=23,
label='месяц размещения объявления', figsize=(15, 5));
plt.minorticks_on()
plt.grid(which='major', color = '#444', linewidth = 0.5)
plt.grid(which='minor', color='#aaa', ls=':')
plt.xlabel('Месяц размещения объявления')
plt.ylabel('Количество объявлений');

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️  Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Интересно, почему февраль (самый короткий месяц) опережает все месяцы — ?__

# %% [markdown]
# **Выводы:**
#
# - **общая площадь** - в объявлениях представлены квартиры от 21 до 240 квадратных метров, медианным значением является 51 квадратный метр. Из гистограммы можем заментить что больше всего объявлений по продаже квартир 21, 43 и 45 квадратных метров. Самый часто встречающийся размер квартир в объявлениях - от 40 до 68 квадратных метров;
# - **жилая площадь** - в обявлениях встречаются размеры от 9.1 до 154 кв.м.. Самый распространенный размер жилой площади от 18,7 до 41 кв.м., на графике есть провал от 21 до 27 кв.м., смею предположить, что это может быть связано с большим количством квартир типовых планировок, в которых не было жилой площади такого размера;
# - **площадь кухни** - кухни представлены в размерах от 4.0 до 70 кв.м., возможно самые минимальные размеры указаны для студий, где сложно на глаз определить ее размер. Чаще всего встречаются кухни от 7 до 11.4 кв.м., медианным значением является кухня 9 кв.м., на графике видно, что больше всего объявлений с кухнями 6, 7, 9, 10 кв.м.;
# - **цена объекта** - разброс по цене квартир от 0.52 до 30 млн.р., наиболее распространены квартиры в ценовом диапазоне от 3.45 до 6.6 млн.р., на графике видно нормальное распределение цены;
# - **количество комнат** - после обработки данных остались квартиры от студий до 5 комнат. Самые частые объявления о продажах квартир от 1 до 3 комнат. Из графика видно, что чаще всего продают однушки и двушки. Медианным значением является двухкомнатная квартира;
# - **высота потолков** - размер потолков варьируется от 2 до 5 м., объявлений с потолками менее 2.5 м. менее 80шт., на результат анализа данных они не влияют, поэтому не стал тратить время на их удаление. В большинстве объявлений высота варьируется от 2.55 до 2.72 м. Медианное значение 2.65, что типично для большинства домов. График подтверждает указанное, никаких выбросов не обнаружено;
# - **этаж квартиры** - квартирфы в объявлениях распределились от 1 до 33 этажей. самые часто встречающиеся этажи в объявлениях - от 2 до 8. Медианой является 4 этаж. На графике видно что количество объявлений снижается ступенчато от меньшего количества этажей к большему. Это может быть связано с тем что основная масса домов построена в СССР и являются типовыми, самые массовые дома это пятиэтажки, за ними идут девятиэтажки, далее 12, 16 и 25, в порядке убывания. Поэтому логично, что основная масса квартир продается в пятиэтажках;
# - **тип этажа квартиры («первый», «последний», «другой»)** - В графике по категориям видим вполне логичное распределение объявлений по категориям этажей. Больше всего объявлений в категории другое, гораздо меньше объявлений в категории первый и последний, их число примерно одинаково. Данные выглядят адекватно, так как в каждом доме может быть только один первый этаж, как и последний, в отличии от "других";
# - **общее количество этажей в доме** - Этажность домов в объявлениях разбросана от 1 до 60 этажей. Чаще всего в объявлениях можно встретить 5-16 этаж. Медианный этаж - 9. На графике можно заметить следующую особенность, большая часть объявлений распределилась пиковые значения, 5, 9, 12, 16, 25 этажей. Как я описывал выше вероятно это связано с тем что большая часть города застроена типовыми домами родом из СССР. Самый большой пик приходится на пятиэтажки.
# - **расстояние до центра города в метрах** - Квартиры в объявлениях распределились от 208 до 65968 метров от центра города. Большая часть объявлений распределилась в пределах 10121 - 16502 м. Медианное значение 13242 м. График подтверждает данное утверждение.
# - **расстояние до ближайшего аэропорта** - Квартиры в объявлениях распределились от 0 до 84869 метров от центра аэропорта. Большая часть объявлений распределилась в пределах 18309 - 37429 м. Медианное значение 26941 м. График подтверждает данное утверждение.
# - **расстояние до ближайшего парка** - С расстоянием до ближайшего парка сложнее, в данных огромное количество пропусков и нулей, поэтому попробуем изучить гистограмму. Судя по гистограмме основная масса квартир в которых есть данные находятся на расстоянии от 200 до 700м.
# - **день и месяц публикации объявления** - Большую часть объявлений публикуют в будние дни с понедельника по пятницы, это может быть связано с тем, что  большое количество квартир продается через риэлторов и они не публикуют новые объявления в выходные дни, поэтому у нас остаются только собственники. Если смотреть на статистику по месяцам, можно заметить, что самая низкая активность в летние месяцы, что связано с тем, что большое количество людей уезжает в отпуска, а так же в январе и декабре, что можно связать с тем что перед новым годом люди озабочены другими заботами, а в январские праздники активность падает как со сторны продавцов, так и покупателей.

# %% [markdown]
# ### **Изучим, как быстро продавались квартиры (столбец `days_exposition`).**

# %%
# Изучим как быстро продавались квартиры
data.plot(kind='hist', y='days_exposition', range=(0, 1580), bins=300, label='скорость продажи', figsize=(15, 5))
plt.minorticks_on()
plt.grid(which='major', color = '#444', linewidth = 0.5)
plt.grid(which='minor', color='#aaa', ls=':')
plt.xlabel('Количество дней размещения объявлений')
plt.ylabel('Количество объявлений')
data['days_exposition'].describe()
# Out:
# count    19457.000000
# mean       179.228452
# std        218.059720
# min          3.000000
# 25%         45.000000
# 50%         94.000000
# 75%        229.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Изучив моды, удалим объявления закрытые в 30, 45, 60, 90 дней, так как это срок автоматического снятия объявления с продажи Яндекс.Недвижимости и они могут повлият на данные, а так же уберем все объявления со сроком продажи более 500 дней, чтобы изучить данные в другом масштабе и избавиться от выбросов которые составляют менее 10% данных.

# %%
# Удалим моды в 30, 45, 60, 90 дней, так как это срок автоматического снятия объявления с продажи
# Ограничим срок продажи 500 днями, так как в этом диапазоне находится 90% объявлений.
(data.query('days_exposition != 30 & days_exposition != 45 & days_exposition != 60 & days_exposition != 90')
 .plot(kind='hist', 
       y='days_exposition', 
       range=(0, 500), 
       bins=300, 
       label='скорость продажи', 
       figsize=(15, 5))
)
plt.minorticks_on()
plt.grid(which='major', color = '#444', linewidth = 0.5)
plt.grid(which='minor', color='#aaa', ls=':')
plt.xlabel('Количество дней размещения объявлений')
plt.ylabel('Количество объявлений')
data.query('days_exposition <= 500 & days_exposition != 30 & days_exposition != 45 & days_exposition != 60 & days_exposition != 90')['days_exposition'].describe()
# Out:
# count    16101.000000
# mean       134.623005
# std        122.422352
# min          3.000000
# 25%         38.000000
# 50%         95.000000
# 75%        195.000000
# max        500.000000
# Name: days_exposition, dtype: float64

# %%
# Изучим среднее время размещения объявлений по годам
(
    data.pivot_table(index='year', values='days_exposition', aggfunc='mean')
    .plot(xlabel='Годы', ylabel='Количество дней размещения объявлений', style='o-', figsize=(15, 5))
)
plt.minorticks_on()
plt.grid(which='major', color = '#444', linewidth = 0.5)
plt.grid(which='minor', color='#aaa', ls=':')
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Только использовать с осторожностью, у нас еще больше 3000 непроданных квартир, которых нет в статистике о средней скорости продаж

# %% [markdown]
# **Вывод:**
#
# По изученным данным можно сделать вывод, квартиры продаются как за три дня, так и за 1500. Тем не менее большая часть квартир продается в промежутке от 38 до 195 дней с медианой в 95 дней. Можно предположить, что все объявления со сроком размещения более 200 дней это либо элитное и дорогое жилье которое долго продается, либо платные объявления с автопродлением, которые забыли снять с размещения после продажи, необходимо дальнейшее изучение данных. Очень быстрыми продажами можно считать сделки завершенные за 38 и менее дней, необычно долгими все что свыше 195 дней. Среднее время размещения объявления от 850 дней в 2014 упало до 40 и 20 в 2018 и 2019 соответственно, что можно связать как с ростом количества объявлений с каждым годом, так и с изменением правил размещения на платформе. Возможно изначально на платформе не существовало жесткого ограничения срока одного объявления, либо оно было гораздо мягче.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Интересно посмотреть на изменение средней  скорости продаж по годам__

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Не исследованы моды в 'days_exposition' и как они влияют на скорость продажи, подсказка на что смотреть
#
# [Условия размещения объявлений](https://yandex.ru/support/realty/owner/home/add-ads-housing.html)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделано

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />   Для определения быстрых и долгих продаж оптимальнее ориентироваться на 25-тый и 75-тый квантили

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделано

# %% [markdown]
# ### **Изучим какие факторы больше всего влияют на общую (полную) стоимость объекта.**

# %% [markdown]
# Изучим, зависит ли цена от:
# - общей площади;
# - жилой площади;
# - площади кухни;
# - количества комнат;
# - этажа, на котором расположена квартира (первый, последний, другой);
# - даты размещения (день недели, месяц, год).
#
# **Построим графики, которые покажут зависимость цены от указанных выше параметров.**

# %%
# Изучим зависит ли цена общей площади
(
    data.pivot_table(index='total_area', values='price_mln')
    .plot(xlabel='Общая площадь', ylabel='Цена', style='o', figsize=(15, 5))
)
plt.minorticks_on()
plt.grid(which='major', color = '#444', linewidth = 0.5)
plt.grid(which='minor', color='#aaa', ls=':')
plt.show()
print('Корреляция цены и площади:','\n')
print(data['last_price'].corr(data['total_area']))
# Out:
# Корреляция цены и площади:
#
# 0.7848113389076643

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />  Можно попробовать настроить вид точечных графиков
#
# [5.2. Scatter - график разброса (точки)](https://pyprog.pro/mpl/mpl_scatter.html?ysclid=l65k3vmmqd649359421)
#
# Примеры расчета коэф. корреляции и не только
#
# [Исследуем отношение между переменными](https://dfedorov.spb.ru/pandas/downey/%D0%98%D1%81%D1%81%D0%BB%D0%B5%D0%B4%D1%83%D0%B5%D0%BC%20%D0%BE%D1%82%D0%BD%D0%BE%D1%88%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BC%D0%B5%D0%B6%D0%B4%D1%83%20%D0%BF%D0%B5%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8.html?ysclid=l9ev0utyg728177057)

# %% [markdown]
# **Промежуточный вывод:**
#
# Ожидаемо зависимость цены от общей площади недвижимости оказалась на достаточно высоком уровне, коэффициент корреляции равен 0.78, из чего делаем вывод что при увеличении общей площади квартиры цена так же растет. Есть выбивающиеся значения, что можно списать на элитную недвижимость, которая при меньшей площади чем эконом или комфорт жилье будет иметь гораздо более высокий ценник.

# %%
# Изучим зависит ли цена жилой площади
(
    data.query('living_area > 0').pivot_table(index='living_area', values='price_mln')
    .plot(xlabel='Жилая площадь', ylabel='Цена', style='o', figsize=(15, 5))
)
plt.minorticks_on()
plt.grid(which='major', color = '#444', linewidth = 0.5)
plt.grid(which='minor', color='#aaa', ls=':')
plt.show()
print('Корреляция цены и жилой площади:','\n')
print(data['last_price'].corr(data.query('living_area > 0')['living_area']))
# Out:
# Корреляция цены и жилой площади:
#
# 0.6701379693704812

# %% [markdown]
# **Промежуточный вывод:**
#
# Кореляция цени и жилой площади уже менее выражена, коэфициент равен 0.67, однако зависимость все равно прослеживается, можно связать это с тем, что часто жилая площадь находится в прямой зависимости от жилой, но это справедливо не для всех объявлений, встречаются квартиры с большой общей площадью и относительно низкой жилой.

# %%
# Изучим зависит ли цена от площади кухни
(
    data.query('kitchen_area > 0').pivot_table(index='kitchen_area', values='price_mln')
    .plot(xlabel='Площадь кухни', ylabel='Цена', style='o', figsize=(15, 5))
)
plt.minorticks_on()
plt.grid(which='major', color = '#444', linewidth = 0.5)
plt.grid(which='minor', color='#aaa', ls=':')
plt.show()
print('Корреляция цены и площади кухни:','\n')
print(data['last_price'].corr(data.query('kitchen_area > 0')['kitchen_area']))
# Out:
# Корреляция цены и площади кухни:
#
# 0.605491509352282

# %% [markdown]
# **Промежуточный вывод:**
#
# Зависимость цены от площади кухни есть, но не так ярко выражена, как предыдущие два парметра. Есть квартиры с 10 метровыми кухнями, которые стоят дороже чем с 20 метровыми. Значит для владельцев продающих такие квартиры есть более важные факторы, на которые они опираются при установке цены, чем размер кухни. Например элитность жилья, удаленность от центра, высота потолков и т.д..

# %%
# Изучим зависит ли цена от категории этажа
(
    data.pivot_table(index='floor_category', values='price_mln')
    .plot(xlabel='Категория этажа', ylabel='Цена', style='o-', grid=True, figsize=(15, 5))
)
plt.show()

# %% [markdown]
# **Промежуточный вывод:**
#
# На графике можно увидеть вполне ожидаемое распределение, самымые дорогие квартиры в категории другие, из двух нежеланных этажей самый высокий ценник на последнем этаже, можно связать это с тем, что в отличии от первого, на последнем могут быть видовые квартиры. И очевидно на первых этажах самая низкая стоимость квартир.

# %%
# Изучим зависит ли цена от количества комнат
(
    data.pivot_table(index='rooms', values='price_mln')
    .plot(xlabel='Количество комнат', ylabel='Цена', style='o-', figsize=(15, 5))
)
plt.minorticks_on()
plt.grid(which='major', color = '#444', linewidth = 0.5)
plt.grid(which='minor', color='#aaa', ls=':')
plt.show()
print('Корреляция цены и количества комнат:','\n')
print(data['last_price'].corr(data['rooms']))
# Out:
# Корреляция цены и количества комнат:
#
# 0.4855806493781326

# %% [markdown]
# **Промежуточный вывод:**
#
# Звисимость цены от количества комнат существует, но она еще менее выражена чем от вышеописанных параметров. Можно предположить, что это связано как раз с общей площадью квартир. Существуют однокомнатные квартиры площадь которых больше чем у двухкомнатных, двушки больше трешек и так далее, в связи с этим продавцы могут больше опиратьсяна площадь объекта, чем на количество комнат в нем, так же свою лепту может вносить категория жилья(социальное, эконом, комфорт, бизнес, элитное).

# %%
# Изучим зависит ли цена от времени размещения
# Начнем с дня недели
(
    data.pivot_table(index='weekday', values='price_mln')
    .plot(xlabel='День недели', ylabel='Цена', style='o-', figsize=(15, 5))
)
plt.minorticks_on()
plt.grid(which='major', color = '#444', linewidth = 0.5)
plt.grid(which='minor', color='#aaa', ls=':')
plt.show()

# Изучим месяц размещения
(
    data.pivot_table(index='month', values='price_mln')
    .plot(xlabel='Месяц', ylabel='Цена', style='o-', figsize=(15, 5))
)
plt.minorticks_on()
plt.grid(which='major', color = '#444', linewidth = 0.5)
plt.grid(which='minor', color='#aaa', ls=':')
plt.show()

# Изучим зависимость от года размещения
(
    data.pivot_table(index='year', values='price_mln')
    .plot(xlabel='Год', ylabel='Цена', style='o-', figsize=(15, 5))
)
plt.minorticks_on()
plt.grid(which='major', color = '#444', linewidth = 0.5)
plt.grid(which='minor', color='#aaa', ls=':')
plt.show()

# %%
# Изучим количнство объявлений в каждом году
(
    data.pivot_table(index='year', values='total_area', aggfunc='mean')
    .plot(xlabel='Год', ylabel='Площадь объекта', style='o-', figsize=(15, 5))
)
plt.minorticks_on()
plt.grid(which='major', color = '#444', linewidth = 0.5)
plt.grid(which='minor', color='#aaa', ls=':')
plt.show()

# %%
# Изучим количество объявлений в каждом году
(
    data.pivot_table(index='year', values='total_area', aggfunc='count')
    .plot(xlabel='Год', ylabel='Площадь объекта', style='o-', figsize=(15, 5))
)
plt.minorticks_on()
plt.grid(which='major', color = '#444', linewidth = 0.5)
plt.grid(which='minor', color='#aaa', ls=':')
plt.show()

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Коэффициент корреляции рассчитывается для всех зависимостей из задания, исключая параметры - день недели и месяц — это не эффективно, т.к. это нелинейные параметры
#
# чтобы они стали линейными, январь месяц 2015 года должен стать третьим и т.д., т.е. мы должны сделать перекодировку ...

# %% [markdown]
# **Промежуточный вывод:**
#
# Никакой прямой зависимости от даты размещения (день недели, месяц, год) не существует.
#
# На графиках можно заметить некоторые очевидные факторы, такие как падение цены в летние месяцы, что скорее всего связано с низким спросом из-за сезона отпусков. Однако колебания цены в другие месяцы объяснить сложно. На графике зависимости цены от года размещения можно заметить, что цена квартир с 2014 года резко упала и с 2019 года ситуация начала улучшаться. Однако проанализировав другие косвенные данные мы можем увидеть, что в 2014 году всего 123 объявления, в ноябре и декабре, видимо из-за того,
# что в том году Яндекс.Недвижимость только запустилась для обычных пользователей. Также с каждым годом уменьшается средняя площадь объекта в объявлениях, что можно связать с увеличением количества объявлений год от года. в 2014 году всего 123 объявления, и доля 1-,2- и 3-х комнатных квартир примерно одинакова, однако с увеличением количества объявлений доля 1- и 2-х комнатных квартир постоянно увеличивается, что приводит к постепенному снижению средней площади объекта. Рост площади в 2019 сложно сравнивать с прошлыми годами, так как мы имеем выборку лишь за первые 5 месяцев и количество объявлений не достигло даже 50% от количества объявлений за 2017 и 2018 г.г..

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Если смотреть только на изменение цены по годам мы можем сделать некорректный вывод, что цены падали, а на самом деле цена это параметр на который влияет несколько других факторов, по этой причине можно посмотреть на основные из них:
#
# + изменение кол-ва записей — принять решение о достаточности данных для анализа и сравнения (сравнивать 100 объявлений и 8000, а возможно, что они еще и из разных локаций, не совсем корректно)
# + изменение площади, как основного параметра от которого зависит стоимость квартиры, в 2017-2018 гг. на сервис или рынок ИТ-торговли недвижимостью пришел массовый продавец, и средние значения упали ..., а за ней и цена
# + изменение кол-ва поданных объявлений из разных локаций, т.к. есть питерские квартиры, а есть выборгские квартиры и стоят они по разному, и в разные годы могло быть больше квартир из определенной локации
# + полнота периода для анализа, 2014 и 2019 гг. неполные, а у нас есть сезонные колебания цен, например летнее снижение цен
# + изменение доли дорогих категорий в общей выборке (средние этажи)
#
# и т.д.

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит дополнить  вывод об изменении цен по годам, необходимо учесть другие факторы, которые также изменяются с годами: площадь и кол-во объявлений о продаже (стоит добавить или графики, или сводные таблицы и исследовать взаимное влияние параметров: кол-во записей и изменение средней цены и средней площади в течение лет)
#
#          Цена квартир с 2014 года резко упала, что очевидно зависело от резкого падения курса рубля и как следствие покупательской способности населения, с 2019 года ситуация начала улучшаться.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделано

# %% [markdown]
# ### **Посчитаем среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделим населённые пункты с самой высокой и низкой стоимостью квадратного метра.**

# %%
top_10_localities = data['short_locality_name'].value_counts().head(10)

price_sqm_locality = (data
                      .query('short_locality_name in @top_10_localities.index')
                      .pivot_table(index='short_locality_name', values='price_sqm', aggfunc='median')
                      .sort_values(by='price_sqm', ascending=False)
                     )
display(price_sqm_locality)
price_sqm_locality.plot(kind='barh', xlabel='Населенный пункт', ylabel='Цена кв.м.', style='o-', figsize=(15, 5))
plt.minorticks_on()
plt.grid(which='major', color = '#444', linewidth = 0.5)
plt.grid(which='minor', color='#aaa', ls=':')
# Out:
#                      price_sqm
# short_locality_name
# Санкт-Петербург       104000.0
# Пушкин                 99706.0
# Кудрово                95435.0
# Парголово              91516.0
# Мурино                 85714.0
# Шушары                 76666.0
# Колпино                74723.5
# Гатчина                67695.0
# Всеволожск             65667.0
# Выборг                 58416.5

# %% [markdown]
# **Промежуточный вывод**
#
# В топ-10 по количествую объявлений, самый высокий ценник за квадратный метр ожидаемо оказался в Санкт-Петербурге, самая низкая цена квадратного метра во Выборге. Так же стоит заметить, что многие представленные отдельно населенные пункты фактически уже являются Санкт-Петербургом.

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />      Можно развернуть график
#
#      kind='barh'

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделано

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />ТОП-10 рассчитан корректно, после восстановления данных вывод может поменяться

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Недостаточно найти числа, стоит их показать красиво, удобно и наглядно, чтобы одного взгляда хватило, где самые самые, а где подешевле 📊

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделано

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Постер поможет выбирать вид графиков](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)

# %% [markdown]
# ### **Ранее мы посчитали расстояние до центра в километрах. Теперь выделим квартиры в Санкт-Петербурге с помощью столбца `short_locality_name` и вычислим среднюю цену каждого километра. Опишем, как стоимость объектов зависит от расстояния до центра города.**

# %%
data_spb = data.query('short_locality_name == "Санкт-Петербург"')

price_per_km = (data_spb
               .pivot_table(index='dist_center_km', values='price_mln', aggfunc='mean'))
price_per_km.plot(style='o-', figsize=(15, 5));
display(price_per_km)
plt.minorticks_on()
plt.grid(which='major', color = '#444', linewidth = 0.5)
plt.grid(which='minor', color='#aaa', ls=':')
print('Корреляция цены и расстояния от центра:','\n')
print(data['last_price'].corr(data['dist_center_km']))
# Out:
#                 price_mln
# dist_center_km
# 0.0             11.290769
# 1.0             11.472973
# 2.0             10.634690
# 3.0              9.456236
# 4.0             10.144255
# 5.0             10.567851
# 6.0              9.356094
# 7.0              9.220585
# 8.0              8.700280
# 9.0              6.789064
# 10.0             6.295039
# 11.0             6.032832
# 12.0             5.888378
# 13.0             6.028305
# 14.0             5.568363
# 15.0             5.779807
# 16.0             5.349005
# 17.0             5.220698
# 18.0             4.905717
# 19.0             5.051410
# 20.0             5.962165
# 21.0             5.446840
# 22.0             5.404070
# 23.0             4.679963
# 24.0             3.854430
# 25.0             3.974954
# 26.0             4.014287
# 27.0             8.300000
# 28.0             5.026429
# 29.0             4.236667
# Корреляция цены и расстояния от центра:
#
# -0.3398378537042369

# %%
# Проверим почему такой пик на 27 километре
data_spb.query('dist_center_km == 27')
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 728             13    14350000        74.0           2017-11-28      2
# 5820             6     2250000        32.0           2018-02-27      1
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 728             3.13             5         30.0      3         False  ...
# 5820            2.60             2         16.5      2         False  ...
#
#       days_exposition  short_locality_name  distance_from_center  price_sqm  \
# 728             128.0      Санкт-Петербург               область     193918
# 5820            178.0      Санкт-Петербург               область      70312
#
#      price_mln  weekday  month  year  floor_category  dist_center_km
# 728      14.35        1     11  2017          другой            27.0
# 5820      2.25        1      2  2018       последний            27.0
#
# [2 rows x 31 columns]

# %%
# Проверим почему появились провалы и пики
data_spb_3_km = data_spb.query('dist_center_km == 3')['floor_category'].value_counts()
print(data_spb_3_km)
print('Средняя площадь квартир на данном километре:', round(data.query('dist_center_km == 3')['total_area'].mean(), 1))
print('Количество квартир первого и последнего этажей -', round(((data_spb_3_km.iloc[1] + data_spb_3_km.iloc[2]) / (data_spb_3_km.iloc[1] + data_spb_3_km.iloc[2] + data_spb_3_km.iloc[0])) * 100, 2), '%')
# Out:
# другой       179
# последний     72
# первый        51
# Name: floor_category, dtype: int64
# Средняя площадь квартир на данном километре: 81.6
# Количество квартир первого и последнего этажей - 40.73 %

# %%
data_spb_5_km = data_spb.query('dist_center_km == 5')['floor_category'].value_counts()
print(data_spb_5_km)
print('Средняя площадь квартир на данном километре:', round(data.query('dist_center_km == 5')['total_area'].mean(), 1))
print('Количество квартир первого и последнего этажей -', round(((data_spb_5_km.iloc[1] + data_spb_5_km.iloc[2]) / (data_spb_5_km.iloc[1] + data_spb_5_km.iloc[2] + data_spb_5_km.iloc[0])) * 100, 2), '%')
# Out:
# другой       604
# последний    115
# первый        69
# Name: floor_category, dtype: int64
# Средняя площадь квартир на данном километре: 81.6
# Количество квартир первого и последнего этажей - 23.35 %

# %%
data_spb_8_km = data_spb.query('dist_center_km == 8')['floor_category'].value_counts()
print(data_spb_8_km)
print('Средняя площадь квартир на данном километре:', round(data.query('dist_center_km == 8')['total_area'].mean(), 1))
print('Количество квартир первого и последнего этажей -', round(((data_spb_8_km.iloc[1] + data_spb_8_km.iloc[2]) / (data_spb_8_km.iloc[1] + data_spb_8_km.iloc[2] + data_spb_8_km.iloc[0])) * 100, 2), '%')
# Out:
# другой       458
# последний     63
# первый        51
# Name: floor_category, dtype: int64
# Средняя площадь квартир на данном километре: 69.3
# Количество квартир первого и последнего этажей - 19.93 %

# %%
data_spb_9_km = data_spb.query('dist_center_km == 9')['floor_category'].value_counts()
print(data_spb_5_km)
print('Средняя площадь квартир на данном километре:', round(data.query('dist_center_km == 9')['total_area'].mean(), 1))
print('Количество квартир первого и последнего этажей -', round(((data_spb_9_km.iloc[1] + data_spb_9_km.iloc[2]) / (data_spb_9_km.iloc[1] + data_spb_9_km.iloc[2] + data_spb_9_km.iloc[0])) * 100, 2), '%')
# Out:
# другой       604
# последний    115
# первый        69
# Name: floor_category, dtype: int64
# Средняя площадь квартир на данном километре: 58.6
# Количество квартир первого и последнего этажей - 23.5 %

# %% [markdown]
# **Промежуточный вывод**
#
# Коэффициент корреляции ревен -0.34, что говорит нам о том, что зависимость есть, но не очень высокая, тем не менее на графике видно, что самая высокая цена за квадратный метр находится в 2-километровой зоне вокруг центра города. Очевидно что при удалении от центра цена квадратного метра стабильно падает, но есть некоторые выбивающиеся значения, например цены в 3 километрах от центра ниже, чем цены в 5 км.. Это может быть связано с инфраструктурой, состоянием домов в разных районах города, наличием элитного жилья и прочие факторы, так же возможна связь с количеством квартир разных категорий этажа. Там где первый и последний занимают около 40% можно наблюдать провалы на графике, а где их доля около 20% небольшие пики. Помимо категорий этажа, на среднюю цену на каждом километре влияет площадь объектов на данном километре, если средняя площадь низкая, соответственно низкая и средняя цена. Так же есть пик на расстоянии 27 км. от центра, это связано с тем, что там всего 2 объявления, одна квартира за 2.25 млн. и вторая за 14.35 млн., что установило среднюю цену на уровень 8.3 млн..

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Молодец, у тебя получилось сгруппировать и построить график изменения средней цены кв. метра в зависимости от расстояния от центра
#
#
# Для выполнения 5-го пункта стоит поменять параметр расчета с цены за квадрат на общую стоимость квартиры
#
#
#         5.	Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит изучить записи, которые привели к выбросу на 27-м км.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделал, добавил в вывод

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит посмотреть на количество квартир разных категорий (первый, последний, другой), которые продаются на 3-м км. и 5-ом ... и какую долю они занимают на каждом километре, чтобы объяснить пик  и провал в центре

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Тоже добавил в вывод

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Супер. Выводы есть, а расчетов нету :) стоит добавить
#
#
#         Стоит изучить записи, которые привели к выбросу на 27-м км.
#
#         Стоит посмотреть на количество квартир разных категорий (первый, последний, другой), которые продаются на 3-м км. и 5-ом ... и какую долю они занимают на каждом километре, чтобы объяснить пик и провал в центре

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Тоже добавил

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# **Была прведена большая работа по предобработке данных:**
#
# - определены пропущенные значения
# - заполнены пропущенные значения там, где это возможно
# - изменены типы данных, для уменьшения используемой памяти и отображаемого вида в таблице
# - устранены неявные дубликаты в названиях населённых пунктов
# - устранены редкие и выбивающиеся значения (аномалии)
#
# **По результатам исследования мы узнали что наиболее значимыми пунктами при формировании цены на квартиру являются:**
# - **общая площадь жилья** - продавцы больше ориенируются на площадь всей квартиры а не на размер отдельных комнат, что косвенно подтверждаеи и график зависимости цены от количества комнат;
# - **категория этажа** - цена на жилье категории этажей "другие" продаются по более высокой стоимости, что связано с низким спросом на категории "первый" и "последний", из-за назкой безопасности в случае первого этажа и возможных проблем с кровлей на последнем, что для Петербурга достаточно частое явление.
# - **удаленность от центра города** - при удалении от центра города цена стабильно падает, на достаточно низкий уровень корреляции -0.34 могут влиять  некоторые выбивающиеся значения, например цены в 3 километрах от центра ниже, чем цены в 5 км.. Это может быть связано с инфраструктурой, состоянием домов в разных районах города, наличием элитного жилья и прочие факторы, так же возможна связь с количеством квартир разных категорий этажа. Там где первый и последний занимают около 40% можно наблюдать провалы на графике, а где их доля около 20% небольшие пики. Помимо категорий этажа, на среднюю цену на каждом километре влияет площадь объектов на данном километре, если средняя площадь низкая, соответственно низкая и средняя цена. Так же есть пик на расстоянии 27 км. от центра, это связано с тем, что там всего 2 объявления, одна квартира за 2.25 млн. и вторая за 14.35 млн., что установило среднюю цену на уровень 8.3 млн..
# - **зависмость года размещения и цены** - прямой зависимости между годом размещения и ценой нет, хотя график и говорит нам об обратном. Однако стоит отметить что со временем колчество объявлений в сервисе увеличивается, в продаже появляется все больше однушек и двушек, из количество становится доминирующим, соответственно средняя цена сдвигается в меньшую сторону по сравнению с годами где распределение по комнатам было более равномерным. Подводя итог можно сказать что не цена с годами падает, а уменьшается средняя площадь продаваемого объекта, что в свою очередь приводит к уменьшению средней цены объекта.
#
# **Стоимость квадратного метра в топ-10 населённых пунктов:**
#
# Дороже всего квадратный метр в Санкт-Петербурге - 103871 р.
# Дешевле всего квадратный метр в Выборге - 58357 р.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Технически вывод хороший, есть сравнения показателей, инсайты, анализ рынка недвижимости, молодец
#
# Осталось перепроверить итоговый вывод после исправления всех комментариев

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Обновил вывод

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Выполнил исследовательскую работу, молодец, показал хороший уровень навыков программирования
#
# Критические ❌ комментарии
#
# + проверить корректность заполнения пропусков синтетическими данными
# + настроить фильтрацию редких значений в п. 2.4
# + подправить гистограммы в п.4.1
# + добавить вывод в п. 4.3
# + добавить график в ТОП-10
# + исследовать аномалии в п.4.5
# + поправить итоговый вывод
#
# С ними важно поработать и исправить
#
# Стоит обратить внимание и на такие комментарии ⚠️
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)
#
# <p> Доп. материал: методы группировки и расчета суммы, средних и т.д.
#
# [Подробное руководство по группировке и агрегированию с помощью pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%B4%D1%80%D0%BE%D0%B1%D0%BD%D0%BE%D0%B5%20%D1%80%D1%83%D0%BA%D0%BE%D0%B2%D0%BE%D0%B4%D1%81%D1%82%D0%B2%D0%BE%20%D0%BF%D0%BE%20%D0%B3%D1%80%D1%83%D0%BF%D0%BF%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B5%20%D0%B8%20%D0%B0%D0%B3%D1%80%D0%B5%D0%B3%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8E%20%D1%81%20%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D1%8C%D1%8E%20pandas.html)
#
#  Интересная функция в библиотеке пандаса
#
# [Понимание функции transform в Pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%BD%D0%B8%D0%BC%D0%B0%D0%BD%D0%B8%D0%B5%20%D1%84%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D0%B8%20transform%20%D0%B2%20Pandas.html)
#
# [Как выбрать определенные столбцы из DataFrame](https://dfedorov.spb.ru/pandas/03.%20%D0%9A%D0%B0%D0%BA%20%D0%B2%D1%8B%D0%B1%D1%80%D0%B0%D1%82%D1%8C%20%D0%BF%D0%BE%D0%B4%D0%BC%D0%BD%D0%BE%D0%B6%D0%B5%D1%81%D1%82%D0%B2%D0%BE%20%D0%B8%D0%B7%20DataFrame_.html?ysclid=l9sps5lt6g576766938)
#
# [How to visualise data using histograms in Pandas](https://practicaldatascience.co.uk/data-science/how-to-visualise-data-using-histograms-in-pandas)

# %% [markdown]
# ## Бонус

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />Диаграмма рассеяния

# %%
# check
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# check
sns.pairplot(data[['last_price', 'total_area', 'rooms', 'cityCenters_nearest']])
plt.gcf().set_size_inches(12,12);

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [5.2. Scatter - график разброса (точки)](https://pyprog.pro/mpl/mpl_scatter.html?ysclid=l65k3vmmqd649359421)

# %%
# check
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='last_price' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'b', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — цена трешки')


data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter', 
        y='last_price' , x='living_area', alpha=0.5, figsize=(15,8), c = 'r', s = 4)
plt.title('Диаграмма рассеяния — Жилая площадь — цена трешки');

# %%
# check
price_pivot_area = data.pivot_table(index='last_price', values=([
    'total_area', 'living_area', 'kitchen_area']), aggfunc='median')
price_pivot_area = price_pivot_area.reset_index()
# Посмотрим на диаграммы рассеяния для столбцов 'total_area', 'living_area', 'kitchen_area'.
for row in ['total_area', 'living_area', 'kitchen_area']:
    sns.relplot(data=price_pivot_area, x='last_price', y=row, kind='scatter')

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - [x] Постройте гистограмму.
#     - [x] Посчитайте среднее и медиану.
#     - [x] В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
